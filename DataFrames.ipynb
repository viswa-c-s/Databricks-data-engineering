# %%
from datetime import date

data = [
    (1, "Alice", 30, "New York",  "2026-01-30"),
    (2, "Bob", 30, "Los Angeles",  "2026-01-30")
]
columns = ["Id", "Name", "Age", "City", "last_updated"]

# %%
df = spark.createDataFrame(data, columns)

# %%
display(df)
