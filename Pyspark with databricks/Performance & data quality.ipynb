# %%
# %sql
create volume if not exists dev_data.test.source_raw

# %%
df_cust = (spark.read.format("csv").options(header = 'true', inferSchema = 'true').load("/Volumes/dev_data/test/source_raw/source_crm/cust_info.csv"))
df_cust.show()

# %%
df_cust.count()

# %%
# 1 dropDuplicates()
df_cust.dropDuplicates()

# %%
df_cust.count()

# %%
df_cust.dropDuplicates(["cst_id"]).count()

# %%
df_cust.dropDuplicates(["cst_id","cst_firstname"]).count()

# %%
df_movies = (spark.read.table("dev_data.test.movies"))

# %%
df_movies.show()

# %%
display(df_movies)

# %%
df_movies.count()

# %%
from pyspark.sql.functions import col
display(df_movies.na.fill({"imdb_rating": 0.0, "studio": "unknown"}))

# %%
display(df_movies)

# %%
df_cust.repartition(4).show()

# %%
df_cust.repartition(4).count()

# %%
df_cust.count()

# %%
df_coal = df_cust.coalesce(1)

# %%
display(df_coal)

# %%
df_orders = (spark.read.table("dev_data.test.orders_online"))

# %%
df_orders = (spark.read.table("dev_data.test.orders_online"))
df_orders.show()

# %%
df_orders.groupBy("customer_id").sum("order_amount").explain(True)
